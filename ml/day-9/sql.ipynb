# %% [markdown]
# 1. Data Definition Language

# %%
import sqlite3

# Connect to database (creates file if it doesn't exist)
conn = sqlite3.connect("company.db")

# Create cursor
cursor = conn.cursor()

# Create table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Employees (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    age INTEGER,
    department TEXT,
    salary REAL
)
""")

# Save changes
conn.commit()

print("Table created successfully!")

# Close connection
conn.close()
# Out:
# Running cells with 'Python 3.14.5' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/user/AppData/Roaming/uv/python/cpython-3.14.5-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Create table with only ONE column
cursor.execute("""
CREATE TABLE IF NOT EXISTS Employees (
    Name TEXT
)
""")

conn.commit()
print("Table with 1 column created successfully!")

conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Drop table
cursor.execute("DROP TABLE IF EXISTS Employees")

# Save changes
conn.commit()

print("Table dropped successfully!")

# Close connection
conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Remove all records (like TRUNCATE)
cursor.execute("DELETE FROM Employees")

# Save changes
conn.commit()

print("All records deleted (table structure kept)!")

# Close connection
conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Rename table
cursor.execute("ALTER TABLE Employees RENAME TO Staff")

# Save changes
conn.commit()

print("Table renamed successfully!")

# Close connection
conn.close()

# %% [markdown]
# 2. Data Manipulation Language

# %%
import sqlite3

conn = sqlite3.connect("company.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS Employees (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT,
    age INTEGER,
    department TEXT,
    salary REAL
)
""")

conn.commit()
conn.close()

print("Table created successfully!")

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Insert a record
cursor.execute("""
INSERT INTO Employees (name, age, department, salary)
VALUES ('Ravi', 25, 'HR', 30000)
""")

# Save changes
conn.commit()

print("Record inserted successfully!")

# Close connection
conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Update record
cursor.execute("""
UPDATE Employees
SET salary = 35000
WHERE name = 'Ravi'
""")

# Save changes
conn.commit()

print("Record updated successfully!")

# Close connection
conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Delete a specific record
cursor.execute("""
DELETE FROM Employees
WHERE name = 'Ravi'
""")

# Save changes
conn.commit()

print("Record deleted successfully!")

# Close connection
conn.close()

# %% [markdown]
# 3. Data Query Language

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Retrieve all records
cursor.execute("SELECT * FROM Employees")

# Fetch data
rows = cursor.fetchall()

# Display data
for row in rows:
    print(row)

# Close connection
conn.close()

# %% [markdown]
# 4. Data Control language

# %%
import sqlite3

conn = sqlite3.connect("company.db")
cursor = conn.cursor()

cursor.execute("SELECT * FROM Employees")

print(cursor.fetchall())

conn.close()

# %%
import sqlite3

conn = sqlite3.connect("company.db")
cursor = conn.cursor()

cursor.execute("SELECT * FROM Employees")

print(cursor.fetchall())

conn.close()

# %% [markdown]
# 5. Transaction Control Language

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Create table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Employees (
    id INTEGER PRIMARY KEY,
    name TEXT,
    salary REAL
)
""")

# Insert data
cursor.execute("INSERT INTO Employees (name, salary) VALUES (?, ?)", ('Ravi', 30000))

# Save changes permanently
conn.commit()

print("Changes committed successfully!")

# Close connection
conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Create table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Employees (
    id INTEGER PRIMARY KEY,
    name TEXT,
    salary REAL
)
""")

# Start transaction (default behavior)
try:
    # Insert data
    cursor.execute("INSERT INTO Employees (name, salary) VALUES (?, ?)", ('Ravi', 30000))

    # Simulate error
    x = 10 / 0   # This will cause an error

    # Commit if everything is fine
    conn.commit()

except:
    print("Error occurred! Rolling back changes...")
    conn.rollback()   # Undo changes

finally:
    conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Create table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Employees (
    id INTEGER PRIMARY KEY,
    name TEXT,
    salary REAL
)
""")

try:
    # Insert first record
    cursor.execute("INSERT INTO Employees (name, salary) VALUES (?, ?)", ('Ravi', 30000))

    # Create savepoint
    cursor.execute("SAVEPOINT sp1")

    # Insert second record
    cursor.execute("INSERT INTO Employees (name, salary) VALUES (?, ?)", ('Rani', 25000))

    # Something goes wrong → rollback to savepoint
    cursor.execute("ROLLBACK TO sp1")

    # Commit remaining changes
    conn.commit()

    print("Rollback to savepoint done!")

except:
    conn.rollback()
    print("Full rollback executed!")

finally:
    conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Create table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Customer (
    CustomerID INTEGER PRIMARY KEY,
    FirstName TEXT,
    LastName TEXT,
    Country TEXT,
    Age INTEGER CHECK (Age >= 0 AND Age <= 99),
    Phone TEXT
)
""")

# Save changes
conn.commit()

print("Customer table created successfully!")

# Close connection
conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Insert multiple records
customers = [
    (1, "Ravi", "Kumar", "India", 25, "9876543210"),
    (2, "Sita", "Devi", "India", 22, "9876543211"),
    (3, "Arjun", "Reddy", "India", 30, "9876543212"),
    (4, "Priya", "Sharma", "India", 28, "9876543213"),
    (5, "Rahul", "Verma", "India", 35, "9876543214"),
    (6, "Anita", "Singh", "India", 27, "9876543215"),
    (7, "Vikram", "Rao", "India", 40, "9876543216"),
    (8, "Kiran", "Patel", "India", 23, "9876543217"),
    (9, "Meena", "Nair", "India", 31, "9876543218"),
    (10, "Raj", "Malhotra", "India", 29, "9876543219"),
    (11, "Pooja", "Gupta", "India", 26, "9876543220"),
    (12, "Amit", "Das", "India", 33, "9876543221"),
    (13, "Sneha", "Iyer", "India", 24, "9876543222"),
    (14, "Rohit", "Yadav", "India", 36, "9876543223"),
    (15, "Neha", "Kapoor", "India", 28, "9876543224"),
    (16, "Suresh", "Naidu", "India", 41, "9876543225"),
    (17, "Divya", "Menon", "India", 21, "9876543226"),
    (18, "Karthik", "Shetty", "India", 34, "9876543227"),
    (19, "Lakshmi", "Rani", "India", 32, "9876543228"),
    (20, "Manoj", "Joshi", "India", 37, "9876543229"),
    (21, "Deepa", "Kulkarni", "India", 29, "9876543230"),
    (22, "Naveen", "Babu", "India", 38, "9876543231"),
    (23, "Swathi", "Reddy", "India", 27, "9876543232"),
    (24, "Harish", "Gowda", "India", 35, "9876543233"),
    (25, "Anil", "Choudhary", "India", 39, "9876543234"),
    (26, "Keerthi", "Rao", "India", 23, "9876543235"),
    (27, "Varun", "Teja", "India", 28, "9876543236"),
    (28, "Bhavana", "Shekar", "India", 26, "9876543237"),
    (29, "Ganesh", "Murthy", "India", 42, "9876543238"),
    (30, "Tejaswini", "Reddy", "India", 24, "9876543239")
]

cursor.executemany("""
INSERT INTO Customer (CustomerID, FirstName, LastName, Country, Age, Phone)
VALUES (?, ?, ?, ?, ?, ?)
""", customers)

# Save changes
conn.commit()

print("30 records inserted successfully!")

# Close connection
conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Execute your query
cursor.execute("SELECT CustomerID, FirstName FROM Customer")

# Fetch results
rows = cursor.fetchall()

# Print results
for row in rows:
    print(row)

# Close connection
conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Execute SELECT query
cursor.execute("SELECT CustomerID, FirstName FROM Customer")

# Fetch data
rows = cursor.fetchall()

# Display data
for row in rows:
    print(row)

# Close connection
conn.close()

# %% [markdown]
# Working with the SELECT Statement

# %% [markdown]
# Example 1: Select Specific Columns

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Correct SELECT query
cursor.execute("SELECT FirstName, LastName FROM Customer")

# Fetch results
rows = cursor.fetchall()

# Print results
for row in rows:
    print(row)

# Close connection
conn.close()

# %% [markdown]
# Example 2: Select All Columns

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Execute query
cursor.execute("SELECT * FROM Customer")

# Fetch all records
rows = cursor.fetchall()

# Display records
for row in rows:
    print(row)

# Close connection
conn.close()

# %% [markdown]
# Example 3: SELECT Statement with WHERE Clause

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Execute query
cursor.execute("SELECT FirstName FROM Customer")

# Fetch results
rows = cursor.fetchall()

# Print results
for row in rows:
    print(row)

# Close connection
conn.close()

# %% [markdown]
# Example 4: SELECT with GROUP BY Clause

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Execute GROUP BY query
cursor.execute("""
SELECT Country, COUNT(*) AS customer_count
FROM Customer
GROUP BY Country
""")

# Fetch results
rows = cursor.fetchall()

# Display results
for row in rows:
    print("Country:", row[0], "| Customers:", row[1])

# Close connection
conn.close()

# %% [markdown]
# Example 5: SELECT with DISTINCT Clause

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Execute DISTINCT query
cursor.execute("SELECT DISTINCT Country FROM Customer")

# Fetch results
rows = cursor.fetchall()

# Display results
for row in rows:
    print(row[0])

# Close connection
conn.close()

# %% [markdown]
# Example 6: SELECT Statement with HAVING Clause

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Execute query
cursor.execute("""
SELECT Country, COUNT(*) AS customer_count
FROM Customer
GROUP BY Country
HAVING COUNT(*) >= 2
""")

# Fetch results
rows = cursor.fetchall()

# Display results
for country, count in rows:
    print(f"Country: {country} | Customers: {count}")

# Close connection
conn.close()

# %% [markdown]
# Example 7: SELECT Statement with ORDER BY clause

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Execute query
cursor.execute("SELECT * FROM Customer ORDER BY Age DESC")

# Fetch results
rows = cursor.fetchall()

# Display results
for row in rows:
    print(row)

# Close connection
conn.close()

# %%
import sqlite3

conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Delete old table
cursor.execute("DROP TABLE IF EXISTS Employees")

# Create correct table
cursor.execute("""
CREATE TABLE Employees (
    EmpID INTEGER PRIMARY KEY,
    Name TEXT,
    Department TEXT,
    Salary INTEGER
)
""")

conn.commit()
conn.close()

print("Table recreated successfully!")

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Insert 50 employees
employees = [
    (1, "John Smith", "HR", 45000),
    (2, "Emma Brown", "IT", 60000),
    (3, "David Lee", "Sales", 52000),
    (4, "Ravi Kumar", "HR", 30000),
    (5, "Sita Devi", "IT", 55000),
    (6, "Arjun Reddy", "Sales", 48000),
    (7, "Priya Sharma", "HR", 47000),
    (8, "Rahul Verma", "IT", 62000),
    (9, "Anita Singh", "Sales", 51000),
    (10, "Vikram Rao", "HR", 53000),
    (11, "Kiran Patel", "IT", 45000),
    (12, "Meena Nair", "Sales", 47000),
    (13, "Raj Malhotra", "HR", 49000),
    (14, "Pooja Gupta", "IT", 61000),
    (15, "Amit Das", "Sales", 50000),
    (16, "Sneha Iyer", "HR", 52000),
    (17, "Rohit Yadav", "IT", 63000),
    (18, "Neha Kapoor", "Sales", 54000),
    (19, "Suresh Naidu", "HR", 55000),
    (20, "Divya Menon", "IT", 58000),
    (21, "Karthik Shetty", "Sales", 56000),
    (22, "Lakshmi Rani", "HR", 46000),
    (23, "Manoj Joshi", "IT", 60000),
    (24, "Deepa Kulkarni", "Sales", 53000),
    (25, "Naveen Babu", "HR", 48000),
    (26, "Swathi Reddy", "IT", 62000),
    (27, "Harish Gowda", "Sales", 51000),
    (28, "Anil Choudhary", "HR", 47000),
    (29, "Keerthi Rao", "IT", 59000),
    (30, "Varun Teja", "Sales", 52000),
    (31, "Bhavana Shekar", "HR", 45000),
    (32, "Ganesh Murthy", "IT", 61000),
    (33, "Tejaswini Reddy", "Sales", 53000),
    (34, "Ajay Kumar", "HR", 49000),
    (35, "Sunita Devi", "IT", 57000),
    (36, "Mahesh Babu", "Sales", 54000),
    (37, "Anjali Mehta", "HR", 50000),
    (38, "Rakesh Singh", "IT", 62000),
    (39, "Kavya Nair", "Sales", 51000),
    (40, "Sanjay Gupta", "HR", 48000),
    (41, "Preeti Sharma", "IT", 60000),
    (42, "Vivek Verma", "Sales", 55000),
    (43, "Aruna Das", "HR", 47000),
    (44, "Nikhil Jain", "IT", 63000),
    (45, "Pallavi Reddy", "Sales", 52000),
    (46, "Harsha Rao", "HR", 49000),
    (47, "Girish Patil", "IT", 61000),
    (48, "Lavanya Iyer", "Sales", 54000)
]

cursor.executemany("""
INSERT INTO Employees (EmpID, Name, Department, Salary)
VALUES (?, ?, ?, ?)
""", employees)

# Save changes
conn.commit()

print("50 employees inserted successfully!")

# Close connection
conn.close()

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

# Execute query
cursor.execute("""
SELECT Name, Department, Salary
FROM Employees
WHERE Salary > 50000
""")

# Fetch results
rows = cursor.fetchall()

# Display results
for name, dept, salary in rows:
    print(f"Name: {name}, Department: {dept}, Salary: {salary}")

# Close connection
conn.close()

# %%
import sqlite3

# Connect to your database
conn = sqlite3.connect("company.db")

# Create cursor
cursor = conn.cursor()

# Your SQL query
query = """
SELECT Name, Department, Salary
FROM Employees
WHERE Salary > 50000;
"""

# Execute query
cursor.execute(query)

# Fetch results
rows = cursor.fetchall()

# Print results
for row in rows:
    print(row)

# Close connection
conn.close()

# %%
import sqlite3

conn = sqlite3.connect("company.db")
cursor = conn.cursor()

query = """
SELECT Name, Department, Salary
FROM Employees
WHERE Salary > 50000;
"""

cursor.execute(query)

rows = cursor.fetchall()

for row in rows:
    print(row)

conn.close()

# %%
import sqlite3

conn = sqlite3.connect("company.db")
cursor = conn.cursor()

cursor.execute("ALTER TABLE Employees ADD COLUMN Age INTEGER")

conn.commit()
conn.close()
